# %%
import numpy as np

data = np.load('results/TD3_NGinxEnv_0.npy')
data
# Out:
# array([-48.05902515, -47.4393247 , -49.23769223, -67.21725095,
#        -59.44934792, -56.88561926, -74.45506718, -58.30896067,
#        -64.2634353 , -59.59500279, -66.83564676, -61.54195233,
#        -57.65795884, -67.68918588, -61.41986067, -48.73538212,
#        -63.08322398, -62.13240479, -56.88967966, -63.98832563,
#        -52.16562944, -67.80223845, -65.6320876 , -38.28648753,
#        -64.16526107, -68.1903343 , -63.01355835, -53.4169149 ,
#        -62.16133597, -56.84426803, -49.96390025, -57.95666729,
#        -56.93296841, -56.94874512, -43.53893558, -56.9193655 ,
#        -64.28119244, -60.32731886, -58.07065762, -49.66923309,
#        -43.79915095, -48.49603834, -46.76284037, -59.58307338,
#        -41.95038973, -46.03886166, -60.35713551, -60.7527034 ,
#        -65.41730091, -50.26425985, -48.88265287, -59.77221445,
#        -47.99555243, -34.21632546, -48.03091329, -49.11616056,
#        -45.36261963, -55.87160309, -56.61839551, -53.03411955,
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(data, marker='o', linestyle='-')
plt.xlabel('Индексы')
plt.ylabel('Значения элементов')
plt.title('График значений элементов numpy массива')
plt.grid(True)
plt.show()
